# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///DadosComprasNet.db')

# %%
connection = engine.connect()

# %%
df_pregao = pd.read_sql('SELECT * FROM BASE_PREGAO', connection, parse_dates=True)

# %%
df_pregao.to_sql('BASE_PREGAO', connection, if_exists='append', index=False)

# %%
pregao = pd.read_csv('BASE_PREGAO.csv', index_col=False)
item = pd.read_csv('BASE_PREGAO_ITEM.csv', index_col=False)
proposta = pd.read_csv('BASE_PREGAO_PROPOSTA.csv', index_col=False)
adjudicacao = pd.read_csv('BASE_PREGAO_ADJUDICACAO.csv', index_col=False)

# %%
pregao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 20 columns):
# Unnamed: 0            9 non-null int64
# numeroPregao          0 non-null float64
# numeroPortaria        9 non-null object
# dataPortaria          9 non-null object
# numeroProcesso        9 non-null object
# tipoPregao            9 non-null object
# tipoCompra            9 non-null object
# objetoPregao          9 non-null object
# uasg                  9 non-null object
# situacaoPregao        1 non-null object
# dataAberturaEdital    9 non-null object
# dataInicioProposta    9 non-null object
# dataFimProposta       9 non-null object
# resultadosPregao      9 non-null object
# declaracoesPregao     9 non-null object
# uriTermosPregao       9 non-null object
# orgaosPregao          9 non-null object
# itensPregao           9 non-null object
# idUasg                9 non-null int64
# idPregao              9 non-null int64
# dtypes: float64(1), int64(3), object(16)
# ...

# %%
adjudicacao.head()
# Out:
#    Unnamed: 0    0  cpfCnpjFornecedor      dataAdjudicacao      idItem  \
# 0           0  NaN                NaN                  NaN         NaN
# 1           0  NaN       2.421421e+12  2014-07-05 16:29:00  13407774.0
# 2           1  NaN       7.284321e+13  2014-07-05 16:29:00  13407775.0
# 3           0  NaN       1.865039e+13  2013-03-12 12:07:00  12852122.0
# 4           0  NaN       2.648053e+13  2013-07-19 14:36:00  11821607.0
#
#                                       nomeFornecedor  \
# 0                                                NaN
# 1                     INTELIG TELECOMUNICACOES LTDA.
# 2               LEVEL 3 COMUNICACOES DO BRASIL LTDA.
# 3  PADRAO NS CONSTRUCAO ACABAMENTOS E REFORMA EIR...
# 4          MOBILIA DF COMERCIO E REPRESENTACOES LTDA
#
#                                           observacao  valorAdjudicado
# 0                                                NaN              NaN
# 1  Adjudicação em grupo da proposta. Fornecedor: ...       1131838.91
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
# 0                    32 non-null object
# cpfCnpjFornecedor    31 non-null float64
# dataAdjudicacao      31 non-null object
# idItem               31 non-null float64
# nomeFornecedor       31 non-null object
# observacao           31 non-null object
# valorAdjudicado      31 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 3.8+ KB

# %%
import sqlite3

# %%
con = sqlite3.connect('teste.db')

# %%
pregao.to_sql('BASE_PREGAO', con, if_exists='append', index=False)
# Out:
# c:\users\cardoso\pycharmprojects\comprasnet\venv\lib\site-packages\pandas\core\generic.py:2713: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
pregao.head()
# Out:
#    Unnamed: 0  numeroPregao  \
# 0           0           NaN
# 1           1           NaN
# 2           2           NaN
# 3           3           NaN
# 4           4           NaN
#
#                                       numeroPortaria         dataPortaria  \
# 0  PORTARIA 47                                   ...  2013-05-17 00:00:00
# 1  Portaria 91                                   ...  2013-11-10 00:00:00
# 2  PORTARIA Nº 58/2013                           ...  2013-04-07 00:00:00
# 3  Portaria 91                                   ...  2013-11-10 00:00:00
# 4  Portaria nº 89, de 12/11/2014                 ...  2014-11-14 00:00:00
#
#                    numeroProcesso  tipoPregao tipoCompra  \
# 0  290.000.097/2013                eletronico      SISPP
# 1  290.000.026/2014                eletronico      SISRP
# 2  0290.000.038/2013               eletronico      SISRP
# 3  290.000.057/2013                eletronico      SISPP
# ...
